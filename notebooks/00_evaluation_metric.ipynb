# %% [markdown]
# # 제3회 풍력발전량 예측 AI 경진대회 평가 산식(Metric)
#
# 평가 산식의 핵심 계산 로직만 포함한 예시 코드입니다.
#
# - `total_score`: 최종 점수
# - `one_minus_nmae`: 1-NMAE
# - `ficr`: 정산금획득률
#
# 동일 로직은 `src/metrics.py`에도 구현되어 있습니다.

# %%
import sys
from pathlib import Path

ROOT = Path('..').resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.metrics import metric
import pandas as pd

# 사용 예시
# answer_df = pd.read_csv('../train/train_labels.csv', encoding='utf-8-sig')
# pred_df = answer_df.copy()  # sanity check
# metric(answer_df[['kpx_group_1','kpx_group_2','kpx_group_3']], pred_df[['kpx_group_1','kpx_group_2','kpx_group_3']])
